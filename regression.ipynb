# %% [markdown]
# # linear regression

# %% [markdown]
# ## Rania Abdullah

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
med_data=pd.read_csv('X_data.csv')
med_data.head(5)
# Out:
#    Unnamed: 0        Age  Systolic_BP  Diastolic_BP  Cholesterol
# 0           0  77.196340    85.288742     80.021878    79.957109
# 1           1  63.529850    99.379736     84.852361   110.382411
# 2           2  69.003986   111.349455    109.850616   100.828246
# 3           3  82.638210    95.056128     79.666851    87.066303
# 4           4  78.346286   109.154591     90.713220    92.511770

# %%
med_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6000 non-null   int64
#  1   Age           6000 non-null   float64
#  2   Systolic_BP   6000 non-null   float64
#  3   Diastolic_BP  6000 non-null   float64
#  4   Cholesterol   6000 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 234.5 KB

# %%
med_data.describe()
# Out:
#         Unnamed: 0          Age  Systolic_BP  Diastolic_BP  Cholesterol
# count  6000.000000  6000.000000  6000.000000   6000.000000  6000.000000
# mean   2999.500000    60.464121   100.694822     90.505547   100.628255
# std    1732.195139     8.564392    10.669267      9.648200    10.433915
# min       0.000000    35.164761    69.675429     62.807105    69.967453
# 25%    1499.750000    54.371941    93.267420     83.641788    93.202373
# 50%    2999.500000    59.831159   100.119926     89.912429   100.060637
# 75%    4499.250000    65.809652   107.439501     96.682405   107.250829
# max    5999.000000   103.279497   151.699660    133.456382   148.233544

# %%
X=med_data['Systolic_BP'].values.reshape(-1,1)

# %%
X
# Out:
# array([[ 85.28874242],
#        [ 99.37973582],
#        [111.349455  ],
#        ...,
#        [ 98.42144624],
#        [106.8092889 ],
#        [ 96.90078368]])

# %%
Y=med_data['Cholesterol'].values

# %%
Y
# Out:
# array([ 79.95710875, 110.38241055, 100.82824559, ..., 120.87595055,
#        106.05221274, 108.62543569])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=100)

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color='blue')
plt.xlabel('Systolic_BP')
plt.ylabel('Cholesterol')
plt.title('Data')
plt.show()

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test) # Trained my model

# %%
y_predict
# Out:
# array([100.72126641,  93.57996065,  95.08586409, ...,  98.60370615,
#        103.79154493, 105.3483104 ])

# %%
y_test
# Out:
# array([ 95.31920757,  77.16334966,  92.42883614, ...,  86.54679979,
#        105.41225292, 118.2582988 ])

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color='blue')
plt.scatter(x_test, y_test, color='y')
plt.plot(x_test, y_predict, color='red')
plt.xlabel('sys')
plt.ylabel('chol')
plt.title(' Data')
plt.show()

# %% [markdown]
# # conclousion

# %% [markdown]
# 1. there is direct relation between the persantage of the Cholesterol and the Systolic blood pressur .
# 2. the Testing Accuracy 14 and Training Accuracy: 16.8 althouhge that there is a direct linear relationship between these parameters.
# 3. I think this model is not efficent and the predicted data is not matching with the actual data.
